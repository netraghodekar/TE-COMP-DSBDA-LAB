# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
 df=pd.read_csv("/content/StudentsPerformance.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.hist();

# %%
df.rename(columns = {'race/ethnicity':'race', 'math score':
'math_score',"reading score":"reading_score", "writing score":
"writing_score",
'parental level of education':'parental_level_of_education'}, inplace = True)
df.head()
# Out:
#    gender     race parental_level_of_education         lunch  \
# 0  female  group B           bachelor's degree      standard
# 1  female  group C                some college      standard
# 2  female  group B             master's degree      standard
# 3    male  group A          associate's degree  free/reduced
# 4    male  group C                some college      standard
#
#   test preparation course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df_gender= pd.get_dummies(df.gender)
df_new=pd.concat([df,df_gender],axis=1)

# %%
df_new.head()
# Out:
#    gender     race parental_level_of_education         lunch  \
# 0  female  group B           bachelor's degree      standard
# 1  female  group C                some college      standard
# 2  female  group B             master's degree      standard
# 3    male  group A          associate's degree  free/reduced
# 4    male  group C                some college      standard
#
#   test preparation course  math_score  reading_score  writing_score  female  \
# 0                    none          72             72             74       1
# 1               completed          69             90             88       1
# 2                    none          90             95             93       1
# 3                    none          47             57             44       0
# 4                    none          76             78             75       0
#
#    male
# 0     0
# 1     0
# 2     0
# 3     1
# 4     1

# %%
import seaborn as sns

# %%
sns.barplot(x="race",y="math_score", hue="gender", data=df_new);

# %%
from matplotlib import pyplot as plt

# %%
df['parental_level_of_education'].value_counts().plot(kind="pie",	 shadow=2, radius=2);

# %%
sns.heatmap(df_new.corr(),annot=True);

# %%
``
